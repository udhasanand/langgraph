# %% [markdown]
# ### Pydantic Data Validation

# %%
from langgraph.graph import StateGraph,START,END
from pydantic import BaseModel

# %%
class State(BaseModel):
    name:str
    
## node function
def example_node(state:State):
    return {"name":"Hello"}

# %%
## stateGraph
builder=StateGraph(State)
builder.add_node("example_node",example_node)

builder.add_edge(START,"example_node")
builder.add_edge("example_node",END)

graph=builder.compile()

# %%
graph.invoke({"name":123})
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 graph.invoke({"name":123})
#
# File ~/workspace/langgraph/venv/lib/python3.12/site-packages/langgraph/pregel/main.py:3913, in Pregel.invoke(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, control, version, **kwargs)
#    3910             chunks.append(chunk)
#    3911 else:
#    3912     # v1: collect interrupts from updates stream
# -> 3913     for chunk in self.stream(
#    3914         input,
#    3915         config,
#    3916         context=context,
#    3917         stream_mode=(
#    3918             ["updates", "values"] if stream_mode == "values" else stream_mode
#    3919         ),
#    3920         print_mode=print_mode,
#    3921         output_keys=output_keys,
#    3922         interrupt_before=interrupt_before,
#    3923         interrupt_after=interrupt_after,
#    3924         durability=durability,
#    3925         control=control,
#    3926         **kwargs,
#    3927     ):
#    3928         if stream_mode == "values":
#    3929             if len(chunk) == 2:
#
# File ~/workspace/langgraph/venv/lib/python3.12/site-packages/langgraph/pregel/main.py:2964, in Pregel.stream(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, control, subgraphs, debug, version, **kwargs)
#    2957             return waiter
#    2959 # Similarly to Bulk Synchronous Parallel / Pregel model
#    2960 # computation proceeds in steps, while there are channel updates.
#    2961 # Channel updates from step N are only visible in step N+1
#    2962 # channels are guaranteed to be immutable for the duration of the step,
#    2963 # with channel updates applied only at the transition between steps.
# -> 2964 while loop.tick():
#    2965     for task in loop.match_cached_writes():
#    2966         loop.output_writes(task.id, task.writes, cached=True)
#
# File ~/workspace/langgraph/venv/lib/python3.12/site-packages/langgraph/pregel/_loop.py:612, in PregelLoop.tick(self)
#     609     return False
#     611 # prepare next tasks
# --> 612 self.tasks = prepare_next_tasks(
#     613     self.checkpoint,
#     614     self.checkpoint_pending_writes,
#     615     self.nodes,
#     616     self.channels,
#     617     self.managed,
#     618     self.config,
#     619     self.step,
#     620     self.stop,
#     621     for_execution=True,
#     622     manager=self.manager,
#     623     store=self.store,
#     624     checkpointer=self.checkpointer,
#     625     trigger_to_nodes=self.trigger_to_nodes,
#     626     updated_channels=self.updated_channels,
#     627     retry_policy=self.retry_policy,
#     628     cache_policy=self.cache_policy,
#     629 )
#     631 # produce debug output
#     632 if self._checkpointer_put_after_previous is not None:
#
# File ~/workspace/langgraph/venv/lib/python3.12/site-packages/langgraph/pregel/_algo.py:491, in prepare_next_tasks(checkpoint, pending_writes, processes, channels, managed, config, step, stop, for_execution, store, checkpointer, manager, trigger_to_nodes, updated_channels, retry_policy, cache_policy)
#     488 # Check if any processes should be run in next step
#     489 # If so, prepare the values to be passed to them
#     490 for name in candidate_nodes:
# --> 491     if task := prepare_single_task(
#     492         (PULL, name),
#     493         None,
#     494         checkpoint=checkpoint,
#     495         checkpoint_id_bytes=checkpoint_id_bytes,
#     496         checkpoint_null_version=null_version,
#     497         pending_writes=pending_writes,
#     498         processes=processes,
#     499         channels=channels,
#     500         managed=managed,
#     501         config=config,
#     502         step=step,
#     503         stop=stop,
#     504         for_execution=for_execution,
#     505         store=store,
#     506         checkpointer=checkpointer,
#     507         manager=manager,
#     508         input_cache=input_cache,
#     509         cache_policy=cache_policy,
#     510         retry_policy=retry_policy,
#     511     ):
#     512         tasks.append(task)
#     513 return {t.id: t for t in tasks}
#
# File ~/workspace/langgraph/venv/lib/python3.12/site-packages/langgraph/pregel/_algo.py:637, in prepare_single_task(task_path, task_id_checksum, checkpoint, checkpoint_id_bytes, checkpoint_null_version, pending_writes, processes, channels, managed, config, step, stop, for_execution, store, checkpointer, manager, input_cache, cache_policy, retry_policy)
#     635 # create task input
#     636 try:
# --> 637     val = _proc_input(
#     638         proc,
#     639         managed,
#     640         channels,
#     641         for_execution=for_execution,
#     642         input_cache=input_cache,
#     643         scratchpad=scratchpad,
#     644     )
#     645     if val is MISSING:
#     646         return
#
# File ~/workspace/langgraph/venv/lib/python3.12/site-packages/langgraph/pregel/_algo.py:1386, in _proc_input(proc, managed, channels, for_execution, scratchpad, input_cache)
#    1384 # If the process has a mapper, apply it to the value
#    1385 if for_execution and proc.mapper is not None:
# -> 1386     val = proc.mapper(val)
#    1388 # Cache the input value
#    1389 if input_cache is not None:
#
# File ~/workspace/langgraph/venv/lib/python3.12/site-packages/langgraph/graph/state.py:1732, in _coerce_state(schema, input)
#    1731 def _coerce_state(schema: type[_S], input: dict[str, Any]) -> _S:
# -> 1732     return schema(**input)
#
# File ~/workspace/langgraph/venv/lib/python3.12/site-packages/pydantic/main.py:263, in BaseModel.__init__(self, **data)
#     261 # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     262 __tracebackhide__ = True
# --> 263 validated_self = self.__pydantic_validator__.validate_python(data, self_instance=self)
#     264 if self is not validated_self:
#     265     warnings.warn(
#     266         'A custom validator is returning a value other than `self`.\n'
#     267         "Returning anything other than `self` from a top level model validator isn't supported when validating via `__init__`.\n"
#     268         'See the `model_validator` docs (https://docs.pydantic.dev/latest/concepts/validators/#model-validators) for more details.',
#     269         stacklevel=2,
#     270     )
#
# ValidationError: 1 validation error for State
# name
#   Input should be a valid string [type=string_type, input_value=123, input_type=int]
#     For further information visit https://errors.pydantic.dev/2.13/v/string_type
# Before task with name 'example_node' and path '('__pregel_pull', 'example_node')'

# %%
graph.invoke({"name":"123"})
# Out:
# {'name': 'Hello'}
